# %% [markdown]
# NLTK is not useful as **named entity recognition** is not correct using** ne_chunk**. Eg: African Amrican is considered to be an ORGANIZATION instead of NORP
#
# Also, **tree2conlltags** produced only I-NP (noun phrase) tags instead of named entities. Hence, dropping NLTK for POS tagging and annotated dataset generation

# %%
# Reference: https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp gdrive/My\ Drive/ADBI\ Project/Dataset/barack.txt .

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %% [markdown]
# ### POS Tagging

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

f = open("barack.txt", 'r')
text = f.read()
tagged_text = preprocess(text)
tagged_text[:10]
# Out:
# [('Barack', 'NNP'),
#  ('Hussein', 'NNP'),
#  ('Obama', 'NNP'),
#  ('II', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('attorney', 'NN'),
#  ('and', 'CC'),
#  ('politician', 'NN')]

# %% [markdown]
# ### Noun Phrase chunking
# A noun phrase, NP, should be formed whenever the chunker finds an optional determiner, DT, followed by any number of adjectives, JJ, and then a noun, NN.

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
nn_chunked = cp.parse(tagged_text)
# print(nn_chunked[0])

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)

# %% [markdown]
# ### Named Entity

# %%
ne_tree = nltk.ne_chunk(pos_tag(word_tokenize(text)))
print(ne_tree)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Hussein/NNP Obama/NNP II/NNP)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   attorney/NN
#   and/CC
#   politician/NN
#   who/WP
#   served/VBD
#   as/IN
#   the/DT
#   44th/CD
#   president/NN
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   from/IN
#   2009/CD
#   to/TO
#   2017/CD
#   ./.
#   A/DT
#   member/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Democratic/NNP Party/NNP)
#   ,/,
#   he/PRP
#   was/VBD
#   the/DT
#   first/JJ
#   (ORGANIZATION African/JJ American/NNP)
#   to/TO
#   be/VB
#   elected/VBN
#   to/TO
#   the/DT
#   presidency/NN
#   ./.
#   He/PRP
#   previously/RB
#   served/VBD
#   as/IN
#   a/DT
#   (GPE U.S./NNP)
#   senator/NN
#   from/IN
#   (GPE Illinois/NNP)
#   from/IN
#   2005/CD
#   to/TO
#   2008/CD
#   ./.
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Honolulu/NNP)
#   ,/,
#   (GPE Hawaii/NNP)
#   ./.
#   After/IN
#   graduating/VBG
#   from/IN
# ...
