# %%
# Reference: https://github.com/explosion/spaCy/blob/master/examples/information_extraction/entity_relations.py
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from __future__ import unicode_literals, print_function

import plac
import spacy

# %%
def main(model="en_core_web_sm"):
    nlp = spacy.load(model)
    print("Loaded model '%s'" % model)
    print("Processing %d texts" % len(TEXTS))

    for text in TEXTS:
        doc = nlp(text)
        print(dir(doc))
        
        relations = extract_currency_relations(doc)
        for r1, r2 in relations:
            print("{:<10}\t{}\t{}".format(r1.text, r2.ent_type_, r2.text))

# %%
TEXTS = [
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
]


#@plac.annotations(model=("Model to load (needs parser and NER)", "positional", None, str))

            
def extract_currency_relations(doc):
    # merge entities and noun chunks into one token
    spans = list(doc.ents) + list(doc.noun_chunks)
    for span in spans:
        span.merge()

    relations = []
    for money in filter(lambda w: w.ent_type_ == "MONEY", doc):
        if money.dep_ in ("attr", "dobj"):
            subject = [w for w in money.head.lefts if w.dep_ == "nsubj"]
            if subject:
                subject = subject[0]
                relations.append((subject, money))
        elif money.dep_ == "pobj" and money.head.dep_ == "prep":
            relations.append((money.head.head, money))
    return relations

          
if __name__ == "__main__":
    main()
# Out:
# Loaded model 'en_core_web_sm'
# Processing 2 texts
# ...

# %%
f = open("gdrive/My Drive/ADBI Project/Dataset/barack.txt", 'r')
text = f.read()

# %%
#TEXTS = [
#    "Net income was $9.4 million compared to the prior year of $2.7 million."
#]
#TEXTS = [text]
TEXTS = ["Dhoni plays cricket and badminton"]
doc = None

model="en_core_web_sm"
nlp = spacy.load(model)
for text in TEXTS:
  doc = nlp(text)
  print(doc.ents)
  #print(doc.sents)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-3968d784e4cf> in <module>()
#       3
#       4 model="en_core_web_sm"
# ----> 5 nlp = spacy.load(model)
#       6 for text in TEXTS:
#       7   doc = nlp(text)
#
# /usr/local/lib/python3.6/dist-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# /usr/local/lib/python3.6/dist-packages/spacy/util.py in load_model(name, **overrides)
#     129             return load_model_from_link(name, **overrides)
#     130         if is_package(name):  # installed as package
# --> 131             return load_model_from_package(name, **overrides)
#     132         if Path(name).exists():  # path to model data directory
# ...

# %%
relations = []
for money in filter(lambda w: w.ent_type_ == "MONEY", doc):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-62a98580c90a> in <module>()
# ----> 1 for sent in doc.sents():
#       2   print(sent)
#
# TypeError: 'generator' object is not callable

# %%
for w in doc:
    if len(w.ent_type_)>0:
      print(w,w.ent_type_)
# Out:
# Barack PERSON
# Hussein PERSON
# Obama PERSON
# II PERSON
# American NORP
# 44th ORDINAL
# the GPE
# United GPE
# States GPE
# 2009 DATE
# to DATE
# 2017 DATE
# the ORG
# Democratic ORG
# Party ORG
# first NORP
# African NORP
# American NORP
# U.S. GPE
# Illinois GPE
# 2005 DATE
# 2008 DATE
# Obama PERSON
# Honolulu GPE
# Hawaii GPE
# Columbia ORG
# University ORG
# 1983 DATE
# Chicago GPE
# 1988 DATE
# Harvard ORG
# Law ORG
# School ORG
# first ORDINAL
# the ORG
# Harvard ORG
# Law ORG
# Review ORG
# the ORG
# University ORG
# of ORG
# Chicago ORG
# Law ORG
# School ORG
# 1992 DATE
# 2004 DATE
# 13th ORDINAL
# three CARDINAL
# the ORG
# Illinois ORG
# Senate ORG
# 1997 DATE
# 2004 DATE
# the ORG
# U.S. ORG
# Senate ORG
# 2004 DATE
# March DATE
# July DATE
# Democratic LAW
# National LAW
# Convention LAW
# November DATE
# Senate ORG
# 2008 DATE
# a DATE
# year DATE
# Hillary PERSON
# Clinton PERSON
# Republican NORP
# John PERSON
# McCain PERSON
# January DATE
# 20 DATE
# , DATE
# ...

# %%
spans = list(doc.ents) + list(doc.noun_chunks)
for span in spans:
  span.merge()

# %%
for w in doc:
  if len(w.ent_type_)>0:
    print(w,w.ent_type_)
# Out:
# Baarck Obama PERSON
# United States GPE

# %%
relations = []
for entity in doc:
  if entity.dep_ in ("attr", "dobj"):
    subject = [w for w in entity.head.lefts if w.dep_ == "nsubj"]
    if subject:
      subject = subject[0]
      relations.append((subject, entity))
    elif entity.dep_ == "pobj" and entity.head.dep_ == "prep":
      relations.append((entity.head.head, entity))

# %%
relations
# Out:
# [(Barack Hussein Obama II, an American attorney),
#  (he, the first African American),
#  (he, the first black president),
#  (he, a civil rights attorney),
#  (He, the 13th district),
#  (He, national attention)]

# %%
count = 0
for entity in doc:
  print(entity,entity.dep_)
  if(count>=5):
    break
  count = count+1
# Out:
# Barack Hussein Obama II nsubj
# is ROOT
# an American attorney attr
# and cc
# politician conj
# who nsubj

# %%
relations = []
for entity in doc:
  if entity.dep_ in ("ROOT"):
    subjects = [w for w in entity.lefts if w.dep_ == "nsubj"]
    objects = [w for w in entity.rights if w.dep_ in ["dobj", "attr","pobj"]]
    if len(subjects)>0 and len(objects)>0:
      print(subjects, entity, objects)
  elif entity.dep_ in ("relcl","prep"):
    temp = entity
    subjects = []
    objects = []
    #subjects = [w for w in entity.lefts if w.dep_ == "nsubj"]
    #objects = [w for w in entity.rights if w.dep_ in ["dobj", "attr","pobj"]]
    while temp.head != temp and (len(subjects)==0 or len(objects)==0):
      for w in temp.lefts:
        if w.dep_=="nsubj":
          subjects.append(w)
      for w in temp.rights:
        if w.dep_ in ["dobj", "attr","pobj"]:
          objects.append(w)
      temp = temp.head
      
    for w in temp.lefts:
      if w.dep_=="nsubj":
        subjects.append(w)
    for w in temp.rights:
      if w.dep_ in ["dobj", "attr","pobj"]:
        objects.append(w)
      
        
#     for w in entity.head.lefts:
#       if w.dep_ == "nsubj":
#         subjects.append(w)
#     for w in entity.head.rights:
#       if w.dep_ in ["dobj", "attr","pobj"]:
#         objects.append(w)
    if len(subjects)>0 and len(objects)>0:
      print(subjects, entity, objects)
# Out:
# [Dhoni] plays [cricket]

# %%
lefts = None
rights = None
for entity in doc:
  if str(entity) == "the first black president":
    lefts = [(w,w.dep_) for w in entity.head.lefts]
    rights = [(w,w.dep_) for w in entity.head.rights]

# %%
lefts
# Out:
# [(where, 'advmod'), (he, 'nsubj')]

# %%
rights
# Out:
# [(the first black president, 'attr')]

# %%
for entity in doc:
  if(entity.dep_=="prep"):
    print(entity.head)
    head_lefts = [(w,w.dep_) for w in entity.head.lefts]
    head_rights = [(w,w.dep_) for w in entity.head.rights]
    lefts = [(w,w.dep_) for w in entity.lefts]
    rights = [(w,w.dep_) for w in entity.rights]
# Out:
# a president

# %%
lefts
# Out:
# []

# %%
rights
# Out:
# [(United States, 'pobj')]

# %%
for entity in doc:
  if(entity.dep_ == "ROOT"):
    print(entity.head==entity)
# Out:
# True

# %%
head_lefts
# Out:
# []

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="199-0" class="displacy" width="650" height="257.0" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dhoni</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">plays</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">cricket</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# ...

# %%
for entity in doc:
  subjects = [w for w in entity.lefts if w.dep_ == "nsubj"]
  objects = [w for w in entity.rights if w.dep_ in ["dobj", "attr","pobj"]]
  if len(subjects)>0 and len(objects)>0:
      print(subjects, entity, objects)
# Out:
# [Dhoni] is [the captain]

# %%
for entity in doc:
  print(entity, entity.dep_, entity.head, entity.head.dep_)
# Out:
# Dhoni nsubj plays ROOT
# plays ROOT plays ROOT
# cricket dobj plays ROOT
# and cc cricket dobj
# badminton conj cricket dobj

# %%
for entity in doc:
  if str(entity)=='cricket':
    lefts = [w for w in entity.lefts]
    rights = [w for w in entity.rights]

# %%
lefts
# Out:
# []

# %%
rights
# Out:
# [and, badminton]

# %%
rights[0].dep_
# Out:
# 'cc'

# %%
rights[1].dep_
# Out:
# 'conj'

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
model="en_core_web_sm"
nlp = spacy.load(model)
