# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. If you're inspired to dig deeper, click the blue "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first import libraries and define functions for plotting the data using `matplotlib`. Depending on the data, not all plots will be made. (Hey, I'm just a simple kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# There is 0 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('./data/wikipedia'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/valid/valid/9502.txt
# /kaggle/input/valid/valid/2145.txt
# /kaggle/input/valid/valid/20364.txt
# /kaggle/input/valid/valid/9092.txt
# /kaggle/input/valid/valid/9631.txt
# /kaggle/input/valid/valid/20033.txt
# /kaggle/input/valid/valid/8074.txt
# /kaggle/input/valid/valid/6634.txt
# /kaggle/input/valid/valid/189.txt
# /kaggle/input/valid/valid/19123.txt
# /kaggle/input/valid/valid/3096.txt
# /kaggle/input/valid/valid/11374.txt
# /kaggle/input/valid/valid/17493.txt
# /kaggle/input/valid/valid/8883.txt
# /kaggle/input/valid/valid/9375.txt
# /kaggle/input/valid/valid/8996.txt
# /kaggle/input/valid/valid/8032.txt
# /kaggle/input/valid/valid/2781.txt
# /kaggle/input/valid/valid/6199.txt
# /kaggle/input/valid/valid/16646.txt
# /kaggle/input/valid/valid/6808.txt
# /kaggle/input/valid/valid/12561.txt
# /kaggle/input/valid/valid/13635.txt
# /kaggle/input/valid/valid/10314.txt
# /kaggle/input/valid/valid/20547.txt
# /kaggle/input/valid/valid/15483.txt
# /kaggle/input/valid/valid/3248.txt
# /kaggle/input/valid/valid/18568.txt
# /kaggle/input/valid/valid/15505.txt
# /kaggle/input/valid/valid/3625.txt
# /kaggle/input/valid/valid/8011.txt
# /kaggle/input/valid/valid/3484.txt
# /kaggle/input/valid/valid/7352.txt
# /kaggle/input/valid/valid/11611.txt
# /kaggle/input/valid/valid/9670.txt
# /kaggle/input/valid/valid/11414.txt
# /kaggle/input/valid/valid/9054.txt
# /kaggle/input/valid/valid/10655.txt
# /kaggle/input/valid/valid/9779.txt
# /kaggle/input/valid/valid/17636.txt
# /kaggle/input/valid/valid/767.txt
# /kaggle/input/valid/valid/2791.txt
# /kaggle/input/valid/valid/10028.txt
# /kaggle/input/valid/valid/9553.txt
# /kaggle/input/valid/valid/18583.txt
# /kaggle/input/valid/valid/19169.txt
# /kaggle/input/valid/valid/14375.txt
# /kaggle/input/valid/valid/111.txt
# /kaggle/input/valid/valid/14540.txt
# /kaggle/input/valid/valid/15237.txt
# /kaggle/input/valid/valid/5407.txt
# /kaggle/input/valid/valid/12330.txt
# /kaggle/input/valid/valid/14817.txt
# /kaggle/input/valid/valid/16922.txt
# /kaggle/input/valid/valid/15543.txt
# /kaggle/input/valid/valid/16367.txt
# /kaggle/input/valid/valid/11850.txt
# /kaggle/input/valid/valid/986.txt
# /kaggle/input/valid/valid/20161.txt
# /kaggle/input/valid/valid/19663.txt
# /kaggle/input/valid/valid/18700.txt
# /kaggle/input/valid/valid/9554.txt
# /kaggle/input/valid/valid/16412.txt
# /kaggle/input/valid/valid/13110.txt
# /kaggle/input/valid/valid/10106.txt
# /kaggle/input/valid/valid/3602.txt
# /kaggle/input/valid/valid/3807.txt
# /kaggle/input/valid/valid/11741.txt
# /kaggle/input/valid/valid/20720.txt
# /kaggle/input/valid/valid/14487.txt
# /kaggle/input/valid/valid/11012.txt
# /kaggle/input/valid/valid/16517.txt
# /kaggle/input/valid/valid/15293.txt
# /kaggle/input/valid/valid/16884.txt
# /kaggle/input/valid/valid/11186.txt
# /kaggle/input/valid/valid/16326.txt
# /kaggle/input/valid/valid/7249.txt
# /kaggle/input/valid/valid/16894.txt
# /kaggle/input/valid/valid/11151.txt
# /kaggle/input/valid/valid/15740.txt
# /kaggle/input/valid/valid/15433.txt
# /kaggle/input/valid/valid/21424.txt
# /kaggle/input/valid/valid/12570.txt
# /kaggle/input/valid/valid/250.txt
# /kaggle/input/valid/valid/602.txt
# /kaggle/input/valid/valid/19738.txt
# /kaggle/input/valid/valid/20987.txt
# /kaggle/input/valid/valid/16527.txt
# /kaggle/input/valid/valid/13999.txt
# /kaggle/input/valid/valid/18532.txt
# /kaggle/input/valid/valid/17108.txt
# /kaggle/input/valid/valid/17799.txt
# /kaggle/input/valid/valid/15684.txt
# /kaggle/input/valid/valid/5413.txt
# /kaggle/input/valid/valid/12871.txt
# /kaggle/input/valid/valid/3104.txt
# /kaggle/input/valid/valid/1784.txt
# /kaggle/input/valid/valid/16080.txt
# /kaggle/input/valid/valid/15042.txt
# /kaggle/input/valid/valid/15089.txt
# /kaggle/input/valid/valid/13589.txt
# /kaggle/input/valid/valid/10841.txt
# /kaggle/input/valid/valid/2528.txt
# /kaggle/input/valid/valid/176.txt
# /kaggle/input/valid/valid/19639.txt
# /kaggle/input/valid/valid/3112.txt
# /kaggle/input/valid/valid/5142.txt
# /kaggle/input/valid/valid/9344.txt
# /kaggle/input/valid/valid/19384.txt
# /kaggle/input/valid/valid/14504.txt
# /kaggle/input/valid/valid/16602.txt
# /kaggle/input/valid/valid/1210.txt
# /kaggle/input/valid/valid/6570.txt
# /kaggle/input/valid/valid/312.txt
# /kaggle/input/valid/valid/16758.txt
# /kaggle/input/valid/valid/4411.txt
# /kaggle/input/valid/valid/2606.txt
# /kaggle/input/valid/valid/552.txt
# /kaggle/input/valid/valid/2135.txt
# /kaggle/input/valid/valid/21331.txt
# /kaggle/input/valid/valid/6820.txt
# /kaggle/input/valid/valid/11397.txt
# /kaggle/input/valid/valid/4986.txt
# /kaggle/input/valid/valid/13407.txt
# /kaggle/input/valid/valid/10930.txt
# /kaggle/input/valid/valid/11851.txt
# /kaggle/input/valid/valid/20774.txt
# /kaggle/input/valid/valid/19653.txt
# /kaggle/input/valid/valid/22102.txt
# /kaggle/input/valid/valid/2137.txt
# /kaggle/input/valid/valid/20239.txt
# /kaggle/input/valid/valid/3176.txt
# /kaggle/input/valid/valid/8971.txt
# /kaggle/input/valid/valid/8146.txt
# /kaggle/input/valid/valid/6296.txt
# /kaggle/input/valid/valid/18754.txt
# /kaggle/input/valid/valid/18775.txt
# /kaggle/input/valid/valid/16164.txt
# /kaggle/input/valid/valid/16637.txt
# /kaggle/input/valid/valid/16158.txt
# /kaggle/input/valid/valid/2991.txt
# /kaggle/input/valid/valid/12778.txt
# /kaggle/input/valid/valid/19839.txt
# /kaggle/input/valid/valid/14468.txt
# /kaggle/input/valid/valid/8597.txt
# /kaggle/input/valid/valid/9493.txt
# /kaggle/input/valid/valid/20334.txt
# /kaggle/input/valid/valid/9982.txt
# /kaggle/input/valid/valid/9658.txt
# /kaggle/input/valid/valid/8251.txt
# /kaggle/input/valid/valid/4822.txt
# /kaggle/input/valid/valid/15993.txt
# /kaggle/input/valid/valid/2643.txt
# /kaggle/input/valid/valid/1265.txt
# /kaggle/input/valid/valid/18150.txt
# /kaggle/input/valid/valid/7026.txt
# /kaggle/input/valid/valid/2251.txt
# /kaggle/input/valid/valid/16591.txt
# /kaggle/input/valid/valid/48.txt
# /kaggle/input/valid/valid/4489.txt
# /kaggle/input/valid/valid/14414.txt
# /kaggle/input/valid/valid/6249.txt
# /kaggle/input/valid/valid/16600.txt
# /kaggle/input/valid/valid/15440.txt
# /kaggle/input/valid/valid/2026.txt
# /kaggle/input/valid/valid/1546.txt
# /kaggle/input/valid/valid/1503.txt
# /kaggle/input/valid/valid/8396.txt
# /kaggle/input/valid/valid/1641.txt
# /kaggle/input/valid/valid/16001.txt
# /kaggle/input/valid/valid/7737.txt
# /kaggle/input/valid/valid/7559.txt
# /kaggle/input/valid/valid/21755.txt
# /kaggle/input/valid/valid/6022.txt
# /kaggle/input/valid/valid/12306.txt
# /kaggle/input/valid/valid/2862.txt
# /kaggle/input/valid/valid/15871.txt
# /kaggle/input/valid/valid/19938.txt
# /kaggle/input/valid/valid/18809.txt
# /kaggle/input/valid/valid/12254.txt
# /kaggle/input/valid/valid/11932.txt
# /kaggle/input/valid/valid/10438.txt
# /kaggle/input/valid/valid/9627.txt
# /kaggle/input/valid/valid/8885.txt
# /kaggle/input/valid/valid/6205.txt
# /kaggle/input/valid/valid/1588.txt
# /kaggle/input/valid/valid/20498.txt
# /kaggle/input/valid/valid/18503.txt
# /kaggle/input/valid/valid/18811.txt
# /kaggle/input/valid/valid/4108.txt
# /kaggle/input/valid/valid/16281.txt
# /kaggle/input/valid/valid/4220.txt
# /kaggle/input/valid/valid/991.txt
# /kaggle/input/valid/valid/13062.txt
# /kaggle/input/valid/valid/13187.txt
# /kaggle/input/valid/valid/18368.txt
# /kaggle/input/valid/valid/1697.txt
# /kaggle/input/valid/valid/12329.txt
# /kaggle/input/valid/valid/6565.txt
# /kaggle/input/valid/valid/21762.txt
# /kaggle/input/valid/valid/4433.txt
# /kaggle/input/valid/valid/5493.txt
# /kaggle/input/valid/valid/3485.txt
# /kaggle/input/valid/valid/7292.txt
# /kaggle/input/valid/valid/9094.txt
# /kaggle/input/valid/valid/3355.txt
# /kaggle/input/valid/valid/4507.txt
# /kaggle/input/valid/valid/15933.txt
# /kaggle/input/valid/valid/19815.txt
# /kaggle/input/valid/valid/16328.txt
# /kaggle/input/valid/valid/9415.txt
# /kaggle/input/valid/valid/18530.txt
# /kaggle/input/valid/valid/7623.txt
# /kaggle/input/valid/valid/10021.txt
# /kaggle/input/valid/valid/3925.txt
# /kaggle/input/valid/valid/16822.txt
# /kaggle/input/valid/valid/4447.txt
# /kaggle/input/valid/valid/6154.txt
# /kaggle/input/valid/valid/17766.txt
# /kaggle/input/valid/valid/4596.txt
# /kaggle/input/valid/valid/9060.txt
# /kaggle/input/valid/valid/6892.txt
# /kaggle/input/valid/valid/4976.txt
# /kaggle/input/valid/valid/13699.txt
# /kaggle/input/valid/valid/15114.txt
# /kaggle/input/valid/valid/19712.txt
# /kaggle/input/valid/valid/12691.txt
# /kaggle/input/valid/valid/7369.txt
# /kaggle/input/valid/valid/13813.txt
# /kaggle/input/valid/valid/593.txt
# /kaggle/input/valid/valid/20598.txt
# /kaggle/input/valid/valid/7514.txt
# /kaggle/input/valid/valid/14006.txt
# /kaggle/input/valid/valid/9009.txt
# /kaggle/input/valid/valid/13346.txt
# /kaggle/input/valid/valid/10362.txt
# /kaggle/input/valid/valid/19151.txt
# /kaggle/input/valid/valid/18596.txt
# /kaggle/input/valid/valid/20229.txt
# /kaggle/input/valid/valid/21757.txt
# /kaggle/input/valid/valid/5287.txt
# /kaggle/input/valid/valid/11800.txt
# /kaggle/input/valid/valid/14663.txt
# /kaggle/input/valid/valid/10585.txt
# /kaggle/input/valid/valid/4191.txt
# /kaggle/input/valid/valid/16958.txt
# /kaggle/input/valid/valid/5876.txt
# /kaggle/input/valid/valid/6665.txt
# /kaggle/input/valid/valid/6599.txt
# /kaggle/input/valid/valid/5971.txt
# /kaggle/input/valid/valid/20573.txt
# /kaggle/input/valid/valid/18058.txt
# /kaggle/input/valid/valid/1521.txt
# /kaggle/input/valid/valid/1186.txt
# /kaggle/input/valid/valid/5713.txt
# /kaggle/input/valid/valid/1961.txt
# /kaggle/input/valid/valid/20140.txt
# /kaggle/input/valid/valid/12943.txt
# /kaggle/input/valid/valid/15079.txt
# /kaggle/input/valid/valid/16548.txt
# /kaggle/input/valid/valid/560.txt
# /kaggle/input/valid/valid/6152.txt
# /kaggle/input/valid/valid/18798.txt
# /kaggle/input/valid/valid/3059.txt
# /kaggle/input/valid/valid/15443.txt
# /kaggle/input/valid/valid/20824.txt
# /kaggle/input/valid/valid/14320.txt
# /kaggle/input/valid/valid/319.txt
# /kaggle/input/valid/valid/11241.txt
# /kaggle/input/valid/valid/16389.txt
# /kaggle/input/valid/valid/911.txt
# /kaggle/input/valid/valid/9944.txt
# /kaggle/input/valid/valid/7635.txt
# /kaggle/input/valid/valid/3030.txt
# /kaggle/input/valid/valid/10461.txt
# /kaggle/input/valid/valid/7595.txt
# /kaggle/input/valid/valid/9297.txt
# /kaggle/input/valid/valid/976.txt
# /kaggle/input/valid/valid/18008.txt
# /kaggle/input/valid/valid/11095.txt
# /kaggle/input/valid/valid/8479.txt
# /kaggle/input/valid/valid/1714.txt
# /kaggle/input/valid/valid/14125.txt
# /kaggle/input/valid/valid/10981.txt
# /kaggle/input/valid/valid/8166.txt
# /kaggle/input/valid/valid/13010.txt
# /kaggle/input/valid/valid/1846.txt
# /kaggle/input/valid/valid/12719.txt
# /kaggle/input/valid/valid/21664.txt
# /kaggle/input/valid/valid/5126.txt
# /kaggle/input/valid/valid/12183.txt
# /kaggle/input/valid/valid/13181.txt
# /kaggle/input/valid/valid/13029.txt
# /kaggle/input/valid/valid/9962.txt
# /kaggle/input/valid/valid/13234.txt
# /kaggle/input/valid/valid/21819.txt
# /kaggle/input/valid/valid/5290.txt
# /kaggle/input/valid/valid/14102.txt
# /kaggle/input/valid/valid/15781.txt
# /kaggle/input/valid/valid/13015.txt
# /kaggle/input/valid/valid/8919.txt
# /kaggle/input/valid/valid/14266.txt
# /kaggle/input/valid/valid/6922.txt
# /kaggle/input/valid/valid/9449.txt
# /kaggle/input/valid/valid/20742.txt
# /kaggle/input/valid/valid/21312.txt
# /kaggle/input/valid/valid/7146.txt
# /kaggle/input/valid/valid/3500.txt
# /kaggle/input/valid/valid/14978.txt
# /kaggle/input/valid/valid/10194.txt
# /kaggle/input/valid/valid/2261.txt
# /kaggle/input/valid/valid/9970.txt
# /kaggle/input/valid/valid/17863.txt
# /kaggle/input/valid/valid/1038.txt
# /kaggle/input/valid/valid/8062.txt
# /kaggle/input/valid/valid/6161.txt
# /kaggle/input/valid/valid/6321.txt
# /kaggle/input/valid/valid/2015.txt
# /kaggle/input/valid/valid/16266.txt
# /kaggle/input/valid/valid/2502.txt
# /kaggle/input/valid/valid/5313.txt
# /kaggle/input/valid/valid/22217.txt
# /kaggle/input/valid/valid/2076.txt
# /kaggle/input/valid/valid/5510.txt
# /kaggle/input/valid/valid/3984.txt
# /kaggle/input/valid/valid/1204.txt
# /kaggle/input/valid/valid/21552.txt
# /kaggle/input/valid/valid/7898.txt
# /kaggle/input/valid/valid/14620.txt
# /kaggle/input/valid/valid/2182.txt
# /kaggle/input/valid/valid/6938.txt
# /kaggle/input/valid/valid/13967.txt
# /kaggle/input/valid/valid/19480.txt
# /kaggle/input/valid/valid/21709.txt
# /kaggle/input/valid/valid/3546.txt
# /kaggle/input/valid/valid/16426.txt
# /kaggle/input/valid/valid/11293.txt
# /kaggle/input/valid/valid/18562.txt
# /kaggle/input/valid/valid/8448.txt
# /kaggle/input/valid/valid/14615.txt
# /kaggle/input/valid/valid/17086.txt
# /kaggle/input/valid/valid/19922.txt
# /kaggle/input/valid/valid/482.txt
# /kaggle/input/valid/valid/12222.txt
# /kaggle/input/valid/valid/20070.txt
# /kaggle/input/valid/valid/11444.txt
# /kaggle/input/valid/valid/16286.txt
# /kaggle/input/valid/valid/3882.txt
# /kaggle/input/valid/valid/6384.txt
# /kaggle/input/valid/valid/14552.txt
# /kaggle/input/valid/valid/1396.txt
# /kaggle/input/valid/valid/12775.txt
# /kaggle/input/valid/valid/16592.txt
# /kaggle/input/valid/valid/3746.txt
# /kaggle/input/valid/valid/14237.txt
# /kaggle/input/valid/valid/5791.txt
# /kaggle/input/valid/valid/244.txt
# /kaggle/input/valid/valid/7891.txt
# /kaggle/input/valid/valid/12610.txt
# /kaggle/input/valid/valid/4848.txt
# /kaggle/input/valid/valid/19306.txt
# /kaggle/input/valid/valid/14556.txt
# /kaggle/input/valid/valid/15231.txt
# /kaggle/input/valid/valid/6848.txt
# /kaggle/input/valid/valid/17619.txt
# /kaggle/input/valid/valid/17925.txt
# /kaggle/input/valid/valid/10736.txt
# /kaggle/input/valid/valid/20387.txt
# /kaggle/input/valid/valid/11878.txt
# /kaggle/input/valid/valid/4277.txt
# /kaggle/input/valid/valid/21902.txt
# /kaggle/input/valid/valid/3450.txt
# /kaggle/input/valid/valid/1567.txt
# /kaggle/input/valid/valid/21158.txt
# /kaggle/input/valid/valid/10094.txt
# /kaggle/input/valid/valid/2012.txt
# /kaggle/input/valid/valid/10624.txt
# /kaggle/input/valid/valid/1020.txt
# /kaggle/input/valid/valid/5804.txt
# /kaggle/input/valid/valid/21898.txt
# /kaggle/input/valid/valid/1880.txt
# /kaggle/input/valid/valid/12097.txt
# /kaggle/input/valid/valid/12314.txt
# /kaggle/input/valid/valid/7824.txt
# /kaggle/input/valid/valid/9318.txt
# /kaggle/input/valid/valid/16081.txt
# /kaggle/input/valid/valid/18968.txt
# /kaggle/input/valid/valid/6431.txt
# /kaggle/input/valid/valid/7929.txt
# /kaggle/input/valid/valid/2604.txt
# /kaggle/input/valid/valid/20076.txt
# /kaggle/input/valid/valid/1368.txt
# /kaggle/input/valid/valid/4626.txt
# /kaggle/input/valid/valid/18971.txt
# /kaggle/input/valid/valid/7489.txt
# /kaggle/input/valid/valid/15910.txt
# /kaggle/input/valid/valid/1692.txt
# /kaggle/input/valid/valid/21445.txt
# /kaggle/input/valid/valid/1736.txt
# /kaggle/input/valid/valid/7499.txt
# /kaggle/input/valid/valid/6969.txt
# /kaggle/input/valid/valid/7398.txt
# /kaggle/input/valid/valid/8027.txt
# /kaggle/input/valid/valid/13319.txt
# /kaggle/input/valid/valid/20054.txt
# /kaggle/input/valid/valid/12106.txt
# /kaggle/input/valid/valid/8565.txt
# /kaggle/input/valid/valid/1487.txt
# /kaggle/input/valid/valid/9305.txt
# /kaggle/input/valid/valid/13550.txt
# /kaggle/input/valid/valid/10575.txt
# /kaggle/input/valid/valid/13396.txt
# /kaggle/input/valid/valid/15537.txt
# /kaggle/input/valid/valid/17899.txt
# /kaggle/input/valid/valid/14693.txt
# /kaggle/input/valid/valid/18289.txt
# /kaggle/input/valid/valid/12801.txt
# /kaggle/input/valid/valid/5217.txt
# /kaggle/input/valid/valid/18354.txt
# /kaggle/input/valid/valid/10350.txt
# /kaggle/input/valid/valid/9477.txt
# /kaggle/input/valid/valid/11618.txt
# /kaggle/input/valid/valid/13501.txt
# /kaggle/input/valid/valid/9347.txt
# /kaggle/input/valid/valid/2876.txt
# /kaggle/input/valid/valid/17814.txt
# /kaggle/input/valid/valid/6632.txt
# /kaggle/input/valid/valid/3641.txt
# /kaggle/input/valid/valid/11719.txt
# /kaggle/input/valid/valid/1224.txt
# /kaggle/input/valid/valid/1442.txt
# /kaggle/input/valid/valid/5476.txt
# /kaggle/input/valid/valid/16916.txt
# /kaggle/input/valid/valid/15570.txt
# /kaggle/input/valid/valid/6782.txt
# /kaggle/input/valid/valid/3196.txt
# /kaggle/input/valid/valid/1940.txt
# /kaggle/input/valid/valid/21769.txt
# /kaggle/input/valid/valid/10645.txt
# /kaggle/input/valid/valid/15695.txt
# /kaggle/input/valid/valid/4921.txt
# /kaggle/input/valid/valid/1472.txt
# /kaggle/input/valid/valid/6194.txt
# /kaggle/input/valid/valid/6694.txt
# /kaggle/input/valid/valid/12463.txt
# /kaggle/input/valid/valid/6739.txt
# /kaggle/input/valid/valid/14897.txt
# /kaggle/input/valid/valid/14902.txt
# /kaggle/input/valid/valid/2040.txt
# /kaggle/input/valid/valid/15439.txt
# /kaggle/input/valid/valid/20513.txt
# /kaggle/input/valid/valid/13950.txt
# /kaggle/input/valid/valid/20646.txt
# /kaggle/input/valid/valid/20215.txt
# /kaggle/input/valid/valid/12040.txt
# /kaggle/input/valid/valid/11179.txt
# /kaggle/input/valid/valid/11557.txt
# /kaggle/input/valid/valid/8131.txt
# /kaggle/input/valid/valid/12786.txt
# /kaggle/input/valid/valid/12192.txt
# /kaggle/input/valid/valid/21723.txt
# /kaggle/input/valid/valid/8015.txt
# /kaggle/input/valid/valid/6584.txt
# /kaggle/input/valid/valid/20274.txt
# /kaggle/input/valid/valid/18556.txt
# /kaggle/input/valid/valid/21414.txt
# /kaggle/input/valid/valid/15739.txt
# /kaggle/input/valid/valid/2995.txt
# /kaggle/input/valid/valid/10653.txt
# /kaggle/input/valid/valid/17422.txt
# /kaggle/input/valid/valid/217.txt
# /kaggle/input/valid/valid/6797.txt
# /kaggle/input/valid/valid/10181.txt
# /kaggle/input/valid/valid/6100.txt
# /kaggle/input/valid/valid/9300.txt
# /kaggle/input/valid/valid/20538.txt
# /kaggle/input/valid/valid/6684.txt
# /kaggle/input/valid/valid/3451.txt
# /kaggle/input/valid/valid/17415.txt
# /kaggle/input/valid/valid/18943.txt
# /kaggle/input/valid/valid/6196.txt
# /kaggle/input/valid/valid/9354.txt
# /kaggle/input/valid/valid/21121.txt
# /kaggle/input/valid/valid/6635.txt
# /kaggle/input/valid/valid/5351.txt
# /kaggle/input/valid/valid/16394.txt
# /kaggle/input/valid/valid/1237.txt
# /kaggle/input/valid/valid/16327.txt
# /kaggle/input/valid/valid/16236.txt
# /kaggle/input/valid/valid/20214.txt
# /kaggle/input/valid/valid/15800.txt
# /kaggle/input/valid/valid/21634.txt
# /kaggle/input/valid/valid/10173.txt
# /kaggle/input/valid/valid/19445.txt
# /kaggle/input/valid/valid/5250.txt
# /kaggle/input/valid/valid/982.txt
# /kaggle/input/valid/valid/22133.txt
# /kaggle/input/valid/valid/19991.txt
# /kaggle/input/valid/valid/2170.txt
# /kaggle/input/valid/valid/18592.txt
# /kaggle/input/valid/valid/6744.txt
# /kaggle/input/valid/valid/5359.txt
# /kaggle/input/valid/valid/13362.txt
# /kaggle/input/valid/valid/20376.txt
# /kaggle/input/valid/valid/4658.txt
# /kaggle/input/valid/valid/21638.txt
# /kaggle/input/valid/valid/9143.txt
# /kaggle/input/valid/valid/16452.txt
# /kaggle/input/valid/valid/4394.txt
# /kaggle/input/valid/valid/2639.txt
# /kaggle/input/valid/valid/8735.txt
# /kaggle/input/valid/valid/19596.txt
# /kaggle/input/valid/valid/5733.txt
# /kaggle/input/valid/valid/10642.txt
# /kaggle/input/valid/valid/8051.txt
# /kaggle/input/valid/valid/15976.txt
# /kaggle/input/valid/valid/7081.txt
# /kaggle/input/valid/valid/3982.txt
# /kaggle/input/valid/valid/11853.txt
# /kaggle/input/valid/valid/9582.txt
# /kaggle/input/valid/valid/12803.txt
# /kaggle/input/valid/valid/11912.txt
# /kaggle/input/valid/valid/10447.txt
# /kaggle/input/valid/valid/17005.txt
# /kaggle/input/valid/valid/13754.txt
# /kaggle/input/valid/valid/1579.txt
# /kaggle/input/valid/valid/16826.txt
# /kaggle/input/valid/valid/3990.txt
# /kaggle/input/valid/valid/9075.txt
# /kaggle/input/valid/valid/18964.txt
# /kaggle/input/valid/valid/6651.txt
# /kaggle/input/valid/valid/20384.txt
# /kaggle/input/valid/valid/6257.txt
# /kaggle/input/valid/valid/6650.txt
# /kaggle/input/valid/valid/350.txt
# /kaggle/input/valid/valid/11840.txt
# /kaggle/input/valid/valid/300.txt
# /kaggle/input/valid/valid/5065.txt
# /kaggle/input/valid/valid/1197.txt
# /kaggle/input/valid/valid/1490.txt
# /kaggle/input/valid/valid/16931.txt
# /kaggle/input/valid/valid/20037.txt
# /kaggle/input/valid/valid/11463.txt
# /kaggle/input/valid/valid/8298.txt
# /kaggle/input/valid/valid/12940.txt
# /kaggle/input/valid/valid/1733.txt
# /kaggle/input/valid/valid/4573.txt
# /kaggle/input/valid/valid/21747.txt
# /kaggle/input/valid/valid/8585.txt
# /kaggle/input/valid/valid/2271.txt
# /kaggle/input/valid/valid/21089.txt
# /kaggle/input/valid/valid/6129.txt
# /kaggle/input/valid/valid/11420.txt
# /kaggle/input/valid/valid/8419.txt
# /kaggle/input/valid/valid/12022.txt
# /kaggle/input/valid/valid/17641.txt
# /kaggle/input/valid/valid/7065.txt
# /kaggle/input/valid/valid/17093.txt
# /kaggle/input/valid/valid/8516.txt
# /kaggle/input/valid/valid/4559.txt
# /kaggle/input/valid/valid/18039.txt
# /kaggle/input/valid/valid/20910.txt
# /kaggle/input/valid/valid/20710.txt
# /kaggle/input/valid/valid/820.txt
# /kaggle/input/valid/valid/7009.txt
# /kaggle/input/valid/valid/17789.txt
# /kaggle/input/valid/valid/18897.txt
# /kaggle/input/valid/valid/12884.txt
# /kaggle/input/valid/valid/1308.txt
# /kaggle/input/valid/valid/21932.txt
# /kaggle/input/valid/valid/21598.txt
# /kaggle/input/valid/valid/9184.txt
# /kaggle/input/valid/valid/18362.txt
# /kaggle/input/valid/valid/9269.txt
# /kaggle/input/valid/valid/18394.txt
# /kaggle/input/valid/valid/16503.txt
# /kaggle/input/valid/valid/21281.txt
# /kaggle/input/valid/valid/7919.txt
# /kaggle/input/valid/valid/15719.txt
# /kaggle/input/valid/valid/17580.txt
# /kaggle/input/valid/valid/19902.txt
# /kaggle/input/valid/valid/813.txt
# /kaggle/input/valid/valid/5195.txt
# /kaggle/input/valid/valid/8562.txt
# /kaggle/input/valid/valid/2596.txt
# /kaggle/input/valid/valid/14669.txt
# /kaggle/input/valid/valid/8320.txt
# /kaggle/input/valid/valid/21125.txt
# /kaggle/input/valid/valid/18845.txt
# /kaggle/input/valid/valid/1743.txt
# /kaggle/input/valid/valid/12147.txt
# /kaggle/input/valid/valid/22241.txt
# /kaggle/input/valid/valid/17375.txt
# /kaggle/input/valid/valid/4325.txt
# /kaggle/input/valid/valid/10468.txt
# /kaggle/input/valid/valid/9505.txt
# /kaggle/input/valid/valid/20030.txt
# /kaggle/input/valid/valid/9916.txt
# /kaggle/input/valid/valid/6068.txt
# /kaggle/input/valid/valid/20544.txt
# /kaggle/input/valid/valid/5467.txt
# /kaggle/input/valid/valid/1744.txt
# /kaggle/input/valid/valid/13717.txt
# /kaggle/input/valid/valid/9237.txt
# /kaggle/input/valid/valid/17.txt
# /kaggle/input/valid/valid/6310.txt
# /kaggle/input/valid/valid/1907.txt
# /kaggle/input/valid/valid/5722.txt
# /kaggle/input/valid/valid/5699.txt
# /kaggle/input/valid/valid/8557.txt
# /kaggle/input/valid/valid/751.txt
# /kaggle/input/valid/valid/1337.txt
# /kaggle/input/valid/valid/7011.txt
# /kaggle/input/valid/valid/21848.txt
# /kaggle/input/valid/valid/22049.txt
# /kaggle/input/valid/valid/1356.txt
# /kaggle/input/valid/valid/50.txt
# /kaggle/input/valid/valid/4895.txt
# /kaggle/input/valid/valid/3427.txt
# /kaggle/input/valid/valid/15775.txt
# /kaggle/input/valid/valid/19570.txt
# /kaggle/input/valid/valid/10842.txt
# /kaggle/input/valid/valid/16534.txt
# /kaggle/input/valid/valid/308.txt
# /kaggle/input/valid/valid/9473.txt
# /kaggle/input/valid/valid/20151.txt
# /kaggle/input/valid/valid/2477.txt
# /kaggle/input/valid/valid/13625.txt
# /kaggle/input/valid/valid/3289.txt
# /kaggle/input/valid/valid/13658.txt
# /kaggle/input/valid/valid/16738.txt
# /kaggle/input/valid/valid/15195.txt
# /kaggle/input/valid/valid/1170.txt
# /kaggle/input/valid/valid/21060.txt
# /kaggle/input/valid/valid/17447.txt
# /kaggle/input/valid/valid/5312.txt
# /kaggle/input/valid/valid/4478.txt
# /kaggle/input/valid/valid/13287.txt
# /kaggle/input/valid/valid/14380.txt
# /kaggle/input/valid/valid/14931.txt
# /kaggle/input/valid/valid/3405.txt
# /kaggle/input/valid/valid/207.txt
# /kaggle/input/valid/valid/4370.txt
# /kaggle/input/valid/valid/9912.txt
# /kaggle/input/valid/valid/10040.txt
# /kaggle/input/valid/valid/8237.txt
# /kaggle/input/valid/valid/8439.txt
# /kaggle/input/valid/valid/21973.txt
# /kaggle/input/valid/valid/8109.txt
# /kaggle/input/valid/valid/3606.txt
# /kaggle/input/valid/valid/20888.txt
# /kaggle/input/valid/valid/1003.txt
# /kaggle/input/valid/valid/39.txt
# /kaggle/input/valid/valid/15451.txt
# /kaggle/input/valid/valid/15149.txt
# /kaggle/input/valid/valid/11442.txt
# /kaggle/input/valid/valid/15322.txt
# /kaggle/input/valid/valid/12731.txt
# /kaggle/input/valid/valid/4464.txt
# /kaggle/input/valid/valid/716.txt
# /kaggle/input/valid/valid/3086.txt
# /kaggle/input/valid/valid/21561.txt
# /kaggle/input/valid/valid/21112.txt
# /kaggle/input/valid/valid/17594.txt
# /kaggle/input/valid/valid/10968.txt
# /kaggle/input/valid/valid/6033.txt
# /kaggle/input/valid/valid/14307.txt
# /kaggle/input/valid/valid/1891.txt
# /kaggle/input/valid/valid/3845.txt
# /kaggle/input/valid/valid/17810.txt
# /kaggle/input/valid/valid/5020.txt
# /kaggle/input/valid/valid/7555.txt
# /kaggle/input/valid/valid/11076.txt
# /kaggle/input/valid/valid/2749.txt
# /kaggle/input/valid/valid/9464.txt
# /kaggle/input/valid/valid/13551.txt
# /kaggle/input/valid/valid/6773.txt
# /kaggle/input/valid/valid/8180.txt
# /kaggle/input/valid/valid/17746.txt
# /kaggle/input/valid/valid/17909.txt
# /kaggle/input/valid/valid/15582.txt
# /kaggle/input/valid/valid/9411.txt
# /kaggle/input/valid/valid/16791.txt
# /kaggle/input/valid/valid/12536.txt
# /kaggle/input/valid/valid/21700.txt
# /kaggle/input/valid/valid/12491.txt
# /kaggle/input/valid/valid/17119.txt
# /kaggle/input/valid/valid/694.txt
# /kaggle/input/valid/valid/18559.txt
# /kaggle/input/valid/valid/5258.txt
# /kaggle/input/valid/valid/13738.txt
# /kaggle/input/valid/valid/6756.txt
# /kaggle/input/valid/valid/9880.txt
# /kaggle/input/valid/valid/21701.txt
# /kaggle/input/valid/valid/1622.txt
# /kaggle/input/valid/valid/16378.txt
# /kaggle/input/valid/valid/1510.txt
# /kaggle/input/valid/valid/21744.txt
# /kaggle/input/valid/valid/5883.txt
# /kaggle/input/valid/valid/17334.txt
# /kaggle/input/valid/valid/17778.txt
# /kaggle/input/valid/valid/20381.txt
# /kaggle/input/valid/valid/5199.txt
# /kaggle/input/valid/valid/8492.txt
# /kaggle/input/valid/valid/18229.txt
# /kaggle/input/valid/valid/3013.txt
# /kaggle/input/valid/valid/3426.txt
# /kaggle/input/valid/valid/3223.txt
# /kaggle/input/valid/valid/12153.txt
# /kaggle/input/valid/valid/18096.txt
# /kaggle/input/valid/valid/8790.txt
# /kaggle/input/valid/valid/19685.txt
# /kaggle/input/valid/valid/8523.txt
# /kaggle/input/valid/valid/21596.txt
# /kaggle/input/valid/valid/9478.txt
# /kaggle/input/valid/valid/14511.txt
# /kaggle/input/valid/valid/18012.txt
# /kaggle/input/valid/valid/13301.txt
# /kaggle/input/valid/valid/19086.txt
# /kaggle/input/valid/valid/147.txt
# /kaggle/input/valid/valid/3986.txt
# /kaggle/input/valid/valid/15345.txt
# /kaggle/input/valid/valid/20822.txt
# /kaggle/input/valid/valid/17931.txt
# /kaggle/input/valid/valid/11621.txt
# /kaggle/input/valid/valid/10705.txt
# /kaggle/input/valid/valid/18097.txt
# /kaggle/input/valid/valid/69.txt
# /kaggle/input/valid/valid/21565.txt
# /kaggle/input/valid/valid/20576.txt
# /kaggle/input/valid/valid/18248.txt
# /kaggle/input/valid/valid/12937.txt
# /kaggle/input/valid/valid/13402.txt
# /kaggle/input/valid/valid/5933.txt
# /kaggle/input/valid/valid/11752.txt
# /kaggle/input/valid/valid/13716.txt
# /kaggle/input/valid/valid/17481.txt
# /kaggle/input/valid/valid/1318.txt
# /kaggle/input/valid/valid/5015.txt
# /kaggle/input/valid/valid/19541.txt
# /kaggle/input/valid/valid/16344.txt
# /kaggle/input/valid/valid/3826.txt
# /kaggle/input/valid/valid/10103.txt
# /kaggle/input/valid/valid/7997.txt
# /kaggle/input/valid/valid/8314.txt
# /kaggle/input/valid/valid/10724.txt
# /kaggle/input/valid/valid/7316.txt
# /kaggle/input/valid/valid/7222.txt
# /kaggle/input/valid/valid/18332.txt
# /kaggle/input/valid/valid/263.txt
# /kaggle/input/valid/valid/17081.txt
# /kaggle/input/valid/valid/4269.txt
# /kaggle/input/valid/valid/4887.txt
# /kaggle/input/valid/valid/16337.txt
# /kaggle/input/valid/valid/17233.txt
# /kaggle/input/valid/valid/14886.txt
# /kaggle/input/valid/valid/12867.txt
# /kaggle/input/valid/valid/2813.txt
# /kaggle/input/valid/valid/3382.txt
# /kaggle/input/valid/valid/10721.txt
# /kaggle/input/valid/valid/201.txt
# /kaggle/input/valid/valid/14748.txt
# /kaggle/input/valid/valid/8821.txt
# /kaggle/input/valid/valid/11898.txt
# /kaggle/input/valid/valid/10675.txt
# /kaggle/input/valid/valid/12576.txt
# /kaggle/input/valid/valid/17333.txt
# /kaggle/input/valid/valid/16928.txt
# /kaggle/input/valid/valid/13888.txt
# /kaggle/input/valid/valid/20863.txt
# /kaggle/input/valid/valid/21684.txt
# /kaggle/input/valid/valid/13415.txt
# /kaggle/input/valid/valid/19589.txt
# /kaggle/input/valid/valid/12138.txt
# /kaggle/input/valid/valid/9942.txt
# /kaggle/input/valid/valid/20007.txt
# /kaggle/input/valid/valid/11955.txt
# /kaggle/input/valid/valid/6285.txt
# /kaggle/input/valid/valid/53.txt
# /kaggle/input/valid/valid/11837.txt
# /kaggle/input/valid/valid/20077.txt
# /kaggle/input/valid/valid/20009.txt
# /kaggle/input/valid/valid/6729.txt
# /kaggle/input/valid/valid/11747.txt
# /kaggle/input/valid/valid/22003.txt
# /kaggle/input/valid/valid/1968.txt
# /kaggle/input/valid/valid/5472.txt
# /kaggle/input/valid/valid/16303.txt
# /kaggle/input/valid/valid/7721.txt
# /kaggle/input/valid/valid/6038.txt
# /kaggle/input/valid/valid/14915.txt
# /kaggle/input/valid/valid/14860.txt
# /kaggle/input/valid/valid/19844.txt
# /kaggle/input/valid/valid/15502.txt
# /kaggle/input/valid/valid/1469.txt
# /kaggle/input/valid/valid/15722.txt
# /kaggle/input/valid/valid/17165.txt
# /kaggle/input/valid/valid/12225.txt
# /kaggle/input/valid/valid/5279.txt
# /kaggle/input/valid/valid/22184.txt
# /kaggle/input/valid/valid/8372.txt
# /kaggle/input/valid/valid/8740.txt
# /kaggle/input/valid/valid/19431.txt
# /kaggle/input/valid/valid/12642.txt
# /kaggle/input/valid/valid/17378.txt
# /kaggle/input/valid/valid/6950.txt
# /kaggle/input/valid/valid/7835.txt
# /kaggle/input/valid/valid/11274.txt
# /kaggle/input/valid/valid/17092.txt
# /kaggle/input/valid/valid/8327.txt
# /kaggle/input/valid/valid/13534.txt
# /kaggle/input/valid/valid/3838.txt
# /kaggle/input/valid/valid/11425.txt
# /kaggle/input/valid/valid/7213.txt
# /kaggle/input/valid/valid/12321.txt
# /kaggle/input/valid/valid/6810.txt
# /kaggle/input/valid/valid/1947.txt
# /kaggle/input/valid/valid/14626.txt
# /kaggle/input/valid/valid/8098.txt
# /kaggle/input/valid/valid/9076.txt
# /kaggle/input/valid/valid/298.txt
# /kaggle/input/valid/valid/19953.txt
# /kaggle/input/valid/valid/20757.txt
# /kaggle/input/valid/valid/890.txt
# /kaggle/input/valid/valid/11869.txt
# /kaggle/input/valid/valid/5051.txt
# /kaggle/input/valid/valid/9666.txt
# /kaggle/input/valid/valid/5921.txt
# /kaggle/input/valid/valid/10064.txt
# /kaggle/input/valid/valid/9909.txt
# /kaggle/input/valid/valid/20324.txt
# /kaggle/input/valid/valid/15622.txt
# /kaggle/input/valid/valid/11762.txt
# /kaggle/input/valid/valid/5007.txt
# /kaggle/input/valid/valid/4009.txt
# /kaggle/input/valid/valid/20906.txt
# /kaggle/input/valid/valid/165.txt
# /kaggle/input/valid/valid/1798.txt
# /kaggle/input/valid/valid/15183.txt
# /kaggle/input/valid/valid/9274.txt
# /kaggle/input/valid/valid/6015.txt
# /kaggle/input/valid/valid/5129.txt
# /kaggle/input/valid/valid/10013.txt
# /kaggle/input/valid/valid/11481.txt
# /kaggle/input/valid/valid/19978.txt
# /kaggle/input/valid/valid/3062.txt
# /kaggle/input/valid/valid/5110.txt
# /kaggle/input/valid/valid/15821.txt
# /kaggle/input/valid/valid/11818.txt
# /kaggle/input/valid/valid/21691.txt
# /kaggle/input/valid/valid/13788.txt
# /kaggle/input/valid/valid/6423.txt
# /kaggle/input/valid/valid/21001.txt
# /kaggle/input/valid/valid/16040.txt
# /kaggle/input/valid/valid/4446.txt
# /kaggle/input/valid/valid/2392.txt
# /kaggle/input/valid/valid/10348.txt
# /kaggle/input/valid/valid/15343.txt
# /kaggle/input/valid/valid/10390.txt
# /kaggle/input/valid/valid/16913.txt
# /kaggle/input/valid/valid/5822.txt
# /kaggle/input/valid/valid/11797.txt
# /kaggle/input/valid/valid/1561.txt
# /kaggle/input/valid/valid/16289.txt
# /kaggle/input/valid/valid/9479.txt
# /kaggle/input/valid/valid/12797.txt
# /kaggle/input/valid/valid/6540.txt
# /kaggle/input/valid/valid/6044.txt
# /kaggle/input/valid/valid/20068.txt
# /kaggle/input/valid/valid/21143.txt
# /kaggle/input/valid/valid/16376.txt
# /kaggle/input/valid/valid/14035.txt
# /kaggle/input/valid/valid/19137.txt
# /kaggle/input/valid/valid/16028.txt
# /kaggle/input/valid/valid/17348.txt
# /kaggle/input/valid/valid/16211.txt
# /kaggle/input/valid/valid/10148.txt
# /kaggle/input/valid/valid/19672.txt
# /kaggle/input/valid/valid/15569.txt
# /kaggle/input/valid/valid/79.txt
# /kaggle/input/valid/valid/18829.txt
# /kaggle/input/valid/valid/6643.txt
# /kaggle/input/valid/valid/6720.txt
# /kaggle/input/valid/valid/19224.txt
# /kaggle/input/valid/valid/488.txt
# /kaggle/input/valid/valid/14890.txt
# /kaggle/input/valid/valid/9540.txt
# /kaggle/input/valid/valid/12081.txt
# /kaggle/input/valid/valid/15397.txt
# /kaggle/input/valid/valid/9433.txt
# /kaggle/input/valid/valid/17235.txt
# /kaggle/input/valid/valid/1747.txt
# /kaggle/input/valid/valid/21180.txt
# /kaggle/input/valid/valid/17090.txt
# /kaggle/input/valid/valid/8295.txt
# /kaggle/input/valid/valid/12936.txt
# /kaggle/input/valid/valid/345.txt
# /kaggle/input/valid/valid/12831.txt
# /kaggle/input/valid/valid/1081.txt
# /kaggle/input/valid/valid/20813.txt
# /kaggle/input/valid/valid/5283.txt
# /kaggle/input/valid/valid/20579.txt
# /kaggle/input/valid/valid/6492.txt
# /kaggle/input/valid/valid/16719.txt
# /kaggle/input/valid/valid/11393.txt
# /kaggle/input/valid/valid/4913.txt
# /kaggle/input/valid/valid/15989.txt
# /kaggle/input/valid/valid/2894.txt
# /kaggle/input/valid/valid/20765.txt
# /kaggle/input/valid/valid/8087.txt
# /kaggle/input/valid/valid/20035.txt
# /kaggle/input/valid/valid/20143.txt
# /kaggle/input/valid/valid/15840.txt
# /kaggle/input/valid/valid/4490.txt
# /kaggle/input/valid/valid/17958.txt
# /kaggle/input/valid/valid/15506.txt
# /kaggle/input/valid/valid/16092.txt
# /kaggle/input/valid/valid/15036.txt
# /kaggle/input/valid/valid/666.txt
# /kaggle/input/valid/valid/10743.txt
# /kaggle/input/valid/valid/5719.txt
# /kaggle/input/valid/valid/20186.txt
# /kaggle/input/valid/valid/17104.txt
# /kaggle/input/valid/valid/16058.txt
# /kaggle/input/valid/valid/16228.txt
# /kaggle/input/valid/valid/5712.txt
# /kaggle/input/valid/valid/5958.txt
# /kaggle/input/valid/valid/4242.txt
# /kaggle/input/valid/valid/5997.txt
# /kaggle/input/valid/valid/2461.txt
# /kaggle/input/valid/valid/12007.txt
# /kaggle/input/valid/valid/18387.txt
# /kaggle/input/valid/valid/4182.txt
# /kaggle/input/valid/valid/16230.txt
# /kaggle/input/valid/valid/18529.txt
# /kaggle/input/valid/valid/13175.txt
# /kaggle/input/valid/valid/16025.txt
# /kaggle/input/valid/valid/8132.txt
# /kaggle/input/valid/valid/12636.txt
# /kaggle/input/valid/valid/15074.txt
# /kaggle/input/valid/valid/15055.txt
# /kaggle/input/valid/valid/944.txt
# /kaggle/input/valid/valid/12999.txt
# /kaggle/input/valid/valid/19430.txt
# /kaggle/input/valid/valid/3099.txt
# /kaggle/input/valid/valid/1650.txt
# /kaggle/input/valid/valid/8570.txt
# /kaggle/input/valid/valid/1228.txt
# /kaggle/input/valid/valid/21626.txt
# /kaggle/input/valid/valid/17065.txt
# /kaggle/input/valid/valid/19214.txt
# /kaggle/input/valid/valid/8257.txt
# /kaggle/input/valid/valid/14450.txt
# /kaggle/input/valid/valid/12162.txt
# /kaggle/input/valid/valid/17666.txt
# /kaggle/input/valid/valid/20546.txt
# /kaggle/input/valid/valid/20692.txt
# /kaggle/input/valid/valid/20595.txt
# /kaggle/input/valid/valid/21123.txt
# /kaggle/input/valid/valid/10236.txt
# /kaggle/input/valid/valid/7044.txt
# /kaggle/input/valid/valid/3364.txt
# /kaggle/input/valid/valid/7250.txt
# /kaggle/input/valid/valid/12361.txt
# /kaggle/input/valid/valid/8279.txt
# /kaggle/input/valid/valid/12260.txt
# /kaggle/input/valid/valid/15045.txt
# /kaggle/input/valid/valid/19282.txt
# /kaggle/input/valid/valid/13368.txt
# /kaggle/input/valid/valid/1423.txt
# /kaggle/input/valid/valid/11501.txt
# /kaggle/input/valid/valid/8201.txt
# /kaggle/input/valid/valid/21879.txt
# /kaggle/input/valid/valid/891.txt
# /kaggle/input/valid/valid/20409.txt
# /kaggle/input/valid/valid/21616.txt
# /kaggle/input/valid/valid/1261.txt
# /kaggle/input/valid/valid/15009.txt
# /kaggle/input/valid/valid/1538.txt
# /kaggle/input/valid/valid/11385.txt
# /kaggle/input/valid/valid/21852.txt
# /kaggle/input/valid/valid/21576.txt
# /kaggle/input/valid/valid/15598.txt
# /kaggle/input/valid/valid/13675.txt
# /kaggle/input/valid/valid/15987.txt
# /kaggle/input/valid/valid/22244.txt
# /kaggle/input/valid/valid/9908.txt
# /kaggle/input/valid/valid/14956.txt
# /kaggle/input/valid/valid/5400.txt
# /kaggle/input/valid/valid/8148.txt
# /kaggle/input/valid/valid/16064.txt
# /kaggle/input/valid/valid/19294.txt
# /kaggle/input/valid/valid/21421.txt
# /kaggle/input/valid/valid/15356.txt
# /kaggle/input/valid/valid/528.txt
# /kaggle/input/valid/valid/11487.txt
# /kaggle/input/valid/valid/13784.txt
# /kaggle/input/valid/valid/13561.txt
# /kaggle/input/valid/valid/9834.txt
# /kaggle/input/valid/valid/14843.txt
# /kaggle/input/valid/valid/2900.txt
# /kaggle/input/valid/valid/9865.txt
# /kaggle/input/valid/valid/9136.txt
# /kaggle/input/valid/valid/18337.txt
# /kaggle/input/valid/valid/11760.txt
# /kaggle/input/valid/valid/3610.txt
# /kaggle/input/valid/valid/19068.txt
# /kaggle/input/valid/valid/2479.txt
# /kaggle/input/valid/valid/691.txt
# /kaggle/input/valid/valid/16969.txt
# /kaggle/input/valid/valid/3110.txt
# /kaggle/input/valid/valid/15349.txt
# /kaggle/input/valid/valid/8856.txt
# /kaggle/input/valid/valid/18840.txt
# /kaggle/input/valid/valid/15054.txt
# /kaggle/input/valid/valid/5045.txt
# /kaggle/input/valid/valid/7596.txt
# /kaggle/input/valid/valid/573.txt
# /kaggle/input/valid/valid/5652.txt
# /kaggle/input/valid/valid/11799.txt
# /kaggle/input/valid/valid/14638.txt
# /kaggle/input/valid/valid/3109.txt
# /kaggle/input/valid/valid/15246.txt
# /kaggle/input/valid/valid/21000.txt
# /kaggle/input/valid/valid/3520.txt
# /kaggle/input/valid/valid/5485.txt
# /kaggle/input/valid/valid/9973.txt
# /kaggle/input/valid/valid/16094.txt
# /kaggle/input/valid/valid/11750.txt
# /kaggle/input/valid/valid/3895.txt
# /kaggle/input/valid/valid/13467.txt
# /kaggle/input/valid/valid/17557.txt
# /kaggle/input/valid/valid/5197.txt
# /kaggle/input/valid/valid/3051.txt
# /kaggle/input/valid/valid/21176.txt
# /kaggle/input/valid/valid/5864.txt
# /kaggle/input/valid/valid/15414.txt
# /kaggle/input/valid/valid/12365.txt
# /kaggle/input/valid/valid/10209.txt
# /kaggle/input/valid/valid/15340.txt
# /kaggle/input/valid/valid/206.txt
# /kaggle/input/valid/valid/6250.txt
# /kaggle/input/valid/valid/10856.txt
# /kaggle/input/valid/valid/18699.txt
# /kaggle/input/valid/valid/14719.txt
# /kaggle/input/valid/valid/8227.txt
# /kaggle/input/valid/valid/2389.txt
# /kaggle/input/valid/valid/15500.txt
# /kaggle/input/valid/valid/4124.txt
# /kaggle/input/valid/valid/9609.txt
# /kaggle/input/valid/valid/11097.txt
# /kaggle/input/valid/valid/4369.txt
# /kaggle/input/valid/valid/14519.txt
# /kaggle/input/valid/valid/22068.txt
# /kaggle/input/valid/valid/17270.txt
# /kaggle/input/valid/valid/11364.txt
# /kaggle/input/valid/valid/14671.txt
# /kaggle/input/valid/valid/3661.txt
# /kaggle/input/valid/valid/4752.txt
# /kaggle/input/valid/valid/900.txt
# /kaggle/input/valid/valid/9667.txt
# /kaggle/input/valid/valid/21513.txt
# /kaggle/input/valid/valid/11764.txt
# /kaggle/input/valid/valid/825.txt
# /kaggle/input/valid/valid/16463.txt
# /kaggle/input/valid/valid/4266.txt
# /kaggle/input/valid/valid/21497.txt
# /kaggle/input/valid/valid/7607.txt
# /kaggle/input/valid/valid/6691.txt
# /kaggle/input/valid/valid/15232.txt
# /kaggle/input/valid/valid/5815.txt
# /kaggle/input/valid/valid/16330.txt
# /kaggle/input/valid/valid/14444.txt
# /kaggle/input/valid/valid/13709.txt
# /kaggle/input/valid/valid/18833.txt
# /kaggle/input/valid/valid/10337.txt
# /kaggle/input/valid/valid/17989.txt
# /kaggle/input/valid/valid/3915.txt
# /kaggle/input/valid/valid/1593.txt
# /kaggle/input/valid/valid/12338.txt
# /kaggle/input/valid/valid/17448.txt
# /kaggle/input/valid/valid/10018.txt
# /kaggle/input/valid/valid/11435.txt
# /kaggle/input/valid/valid/20886.txt
# /kaggle/input/valid/valid/8470.txt
# /kaggle/input/valid/valid/16256.txt
# /kaggle/input/valid/valid/1583.txt
# /kaggle/input/valid/valid/6933.txt
# /kaggle/input/valid/valid/932.txt
# /kaggle/input/valid/valid/1280.txt
# /kaggle/input/valid/valid/10096.txt
# /kaggle/input/valid/valid/14728.txt
# /kaggle/input/valid/valid/1338.txt
# /kaggle/input/valid/valid/9735.txt
# /kaggle/input/valid/valid/1791.txt
# /kaggle/input/valid/valid/6078.txt
# /kaggle/input/valid/valid/3288.txt
# /kaggle/input/valid/valid/18488.txt
# /kaggle/input/valid/valid/5543.txt
# /kaggle/input/valid/valid/14600.txt
# /kaggle/input/valid/valid/20477.txt
# /kaggle/input/valid/valid/10822.txt
# /kaggle/input/valid/valid/15612.txt
# /kaggle/input/valid/valid/1055.txt
# /kaggle/input/valid/valid/5384.txt
# /kaggle/input/valid/valid/8705.txt
# /kaggle/input/valid/valid/2399.txt
# /kaggle/input/valid/valid/6930.txt
# /kaggle/input/valid/valid/15902.txt
# /kaggle/input/valid/valid/22088.txt
# /kaggle/input/valid/valid/20371.txt
# /kaggle/input/valid/valid/781.txt
# /kaggle/input/valid/valid/9976.txt
# /kaggle/input/valid/valid/10851.txt
# /kaggle/input/valid/valid/6192.txt
# /kaggle/input/valid/valid/2657.txt
# /kaggle/input/valid/valid/18711.txt
# /kaggle/input/valid/valid/6805.txt
# /kaggle/input/valid/valid/21759.txt
# /kaggle/input/valid/valid/20802.txt
# /kaggle/input/valid/valid/20486.txt
# /kaggle/input/valid/valid/19211.txt
# /kaggle/input/valid/valid/774.txt
# /kaggle/input/valid/valid/4931.txt
# /kaggle/input/valid/valid/10110.txt
# /kaggle/input/valid/valid/6652.txt
# /kaggle/input/valid/valid/5189.txt
# /kaggle/input/valid/valid/9794.txt
# /kaggle/input/valid/valid/1296.txt
# /kaggle/input/valid/valid/8182.txt
# /kaggle/input/valid/valid/9233.txt
# /kaggle/input/valid/valid/11952.txt
# /kaggle/input/valid/valid/20344.txt
# /kaggle/input/valid/valid/6674.txt
# /kaggle/input/valid/valid/1043.txt
# /kaggle/input/valid/valid/2128.txt
# /kaggle/input/valid/valid/11782.txt
# /kaggle/input/valid/valid/10617.txt
# /kaggle/input/valid/valid/8077.txt
# /kaggle/input/valid/valid/1712.txt
# /kaggle/input/valid/valid/14207.txt
# /kaggle/input/valid/valid/3615.txt
# /kaggle/input/valid/valid/15641.txt
# /kaggle/input/valid/valid/1870.txt
# /kaggle/input/valid/valid/8667.txt
# /kaggle/input/valid/valid/15686.txt
# /kaggle/input/valid/valid/17963.txt
# /kaggle/input/valid/valid/5612.txt
# /kaggle/input/valid/valid/3264.txt
# /kaggle/input/valid/valid/10299.txt
# /kaggle/input/valid/valid/20297.txt
# /kaggle/input/valid/valid/4538.txt
# /kaggle/input/valid/valid/9498.txt
# /kaggle/input/valid/valid/4063.txt
# /kaggle/input/valid/valid/13708.txt
# /kaggle/input/valid/valid/5697.txt
# /kaggle/input/valid/valid/9625.txt
# /kaggle/input/valid/valid/16830.txt
# /kaggle/input/valid/valid/5203.txt
# /kaggle/input/valid/valid/2485.txt
# /kaggle/input/valid/valid/8520.txt
# /kaggle/input/valid/valid/5646.txt
# /kaggle/input/valid/valid/11431.txt
# /kaggle/input/valid/valid/13648.txt
# /kaggle/input/valid/valid/19895.txt
# /kaggle/input/valid/valid/3753.txt
# /kaggle/input/valid/valid/9997.txt
# /kaggle/input/valid/valid/13555.txt
# /kaggle/input/valid/valid/4652.txt
# /kaggle/input/valid/valid/7697.txt
# /kaggle/input/valid/valid/2160.txt
# /kaggle/input/valid/valid/18690.txt
# /kaggle/input/valid/valid/10886.txt
# /kaggle/input/valid/valid/19698.txt
# /kaggle/input/valid/valid/16104.txt
# /kaggle/input/valid/valid/1734.txt
# /kaggle/input/valid/valid/17537.txt
# /kaggle/input/valid/valid/618.txt
# /kaggle/input/valid/valid/8654.txt
# /kaggle/input/valid/valid/13341.txt
# /kaggle/input/valid/valid/14545.txt
# /kaggle/input/valid/valid/21923.txt
# /kaggle/input/valid/valid/1859.txt
# /kaggle/input/valid/valid/20679.txt
# /kaggle/input/valid/valid/8615.txt
# /kaggle/input/valid/valid/2893.txt
# /kaggle/input/valid/valid/15965.txt
# /kaggle/input/valid/valid/22069.txt
# /kaggle/input/valid/valid/9267.txt
# /kaggle/input/valid/valid/4491.txt
# /kaggle/input/valid/valid/8548.txt
# /kaggle/input/valid/valid/17613.txt
# /kaggle/input/valid/valid/9738.txt
# /kaggle/input/valid/valid/2508.txt
# /kaggle/input/valid/valid/9842.txt
# /kaggle/input/valid/valid/21241.txt
# /kaggle/input/valid/valid/14702.txt
# /kaggle/input/valid/valid/8204.txt
# /kaggle/input/valid/valid/7493.txt
# /kaggle/input/valid/valid/19969.txt
# /kaggle/input/valid/valid/2908.txt
# /kaggle/input/valid/valid/15702.txt
# /kaggle/input/valid/valid/17206.txt
# /kaggle/input/valid/valid/15164.txt
# /kaggle/input/valid/valid/20020.txt
# /kaggle/input/valid/valid/6169.txt
# /kaggle/input/valid/valid/9681.txt
# /kaggle/input/valid/valid/8063.txt
# /kaggle/input/valid/valid/18142.txt
# /kaggle/input/valid/valid/347.txt
# /kaggle/input/valid/valid/8718.txt
# /kaggle/input/valid/valid/13492.txt
# /kaggle/input/valid/valid/10788.txt
# /kaggle/input/valid/valid/14428.txt
# /kaggle/input/valid/valid/11392.txt
# /kaggle/input/valid/valid/9187.txt
# /kaggle/input/valid/valid/9600.txt
# /kaggle/input/valid/valid/19924.txt
# /kaggle/input/valid/valid/18920.txt
# /kaggle/input/valid/valid/19916.txt
# /kaggle/input/valid/valid/5897.txt
# /kaggle/input/valid/valid/18089.txt
# /kaggle/input/valid/valid/13390.txt
# /kaggle/input/valid/valid/5727.txt
# /kaggle/input/valid/valid/9034.txt
# /kaggle/input/valid/valid/17400.txt
# /kaggle/input/valid/valid/1600.txt
# /kaggle/input/valid/valid/15160.txt
# /kaggle/input/valid/valid/19824.txt
# /kaggle/input/valid/valid/12191.txt
# /kaggle/input/valid/valid/17969.txt
# /kaggle/input/valid/valid/7953.txt
# /kaggle/input/valid/valid/290.txt
# /kaggle/input/valid/valid/9047.txt
# /kaggle/input/valid/valid/10969.txt
# /kaggle/input/valid/valid/1831.txt
# /kaggle/input/valid/valid/9624.txt
# /kaggle/input/valid/valid/21329.txt
# /kaggle/input/valid/valid/12665.txt
# /kaggle/input/valid/valid/3532.txt
# /kaggle/input/valid/valid/4000.txt
# /kaggle/input/valid/valid/19564.txt
# /kaggle/input/valid/valid/1315.txt
# /kaggle/input/valid/valid/18152.txt
# /kaggle/input/valid/valid/16123.txt
# /kaggle/input/valid/valid/15867.txt
# /kaggle/input/valid/valid/11110.txt
# /kaggle/input/valid/valid/1024.txt
# /kaggle/input/valid/valid/8791.txt
# /kaggle/input/valid/valid/4265.txt
# /kaggle/input/valid/valid/2366.txt
# /kaggle/input/valid/valid/8316.txt
# /kaggle/input/valid/valid/7549.txt
# /kaggle/input/valid/valid/18233.txt
# /kaggle/input/valid/valid/3711.txt
# /kaggle/input/valid/valid/19158.txt
# /kaggle/input/valid/valid/15147.txt
# /kaggle/input/valid/valid/5682.txt
# /kaggle/input/valid/valid/2212.txt
# /kaggle/input/valid/valid/8832.txt
# /kaggle/input/valid/valid/6028.txt
# /kaggle/input/valid/valid/10503.txt
# /kaggle/input/valid/valid/20829.txt
# /kaggle/input/valid/valid/3207.txt
# /kaggle/input/valid/valid/2282.txt
# /kaggle/input/valid/valid/19407.txt
# /kaggle/input/valid/valid/2482.txt
# /kaggle/input/valid/valid/13060.txt
# /kaggle/input/valid/valid/3032.txt
# /kaggle/input/valid/valid/16260.txt
# /kaggle/input/valid/valid/6680.txt
# /kaggle/input/valid/valid/6897.txt
# /kaggle/input/valid/valid/16886.txt
# /kaggle/input/valid/valid/689.txt
# /kaggle/input/valid/valid/19056.txt
# /kaggle/input/valid/valid/16252.txt
# /kaggle/input/valid/valid/9811.txt
# /kaggle/input/valid/valid/17889.txt
# /kaggle/input/valid/valid/16885.txt
# /kaggle/input/valid/valid/13759.txt
# /kaggle/input/valid/valid/7168.txt
# /kaggle/input/valid/valid/18361.txt
# /kaggle/input/valid/valid/8815.txt
# /kaggle/input/valid/valid/21977.txt
# /kaggle/input/valid/valid/11796.txt
# /kaggle/input/valid/valid/17929.txt
# /kaggle/input/valid/valid/914.txt
# /kaggle/input/valid/valid/16359.txt
# /kaggle/input/valid/valid/10075.txt
# /kaggle/input/valid/valid/11924.txt
# /kaggle/input/valid/valid/811.txt
# /kaggle/input/valid/valid/18712.txt
# /kaggle/input/valid/valid/18820.txt
# /kaggle/input/valid/valid/2516.txt
# /kaggle/input/valid/valid/4062.txt
# /kaggle/input/valid/valid/17701.txt
# /kaggle/input/valid/valid/9593.txt
# /kaggle/input/valid/valid/3076.txt
# /kaggle/input/valid/valid/20701.txt
# /kaggle/input/valid/valid/1905.txt
# /kaggle/input/valid/valid/19197.txt
# /kaggle/input/valid/valid/13563.txt
# /kaggle/input/valid/valid/2548.txt
# /kaggle/input/valid/valid/20291.txt
# /kaggle/input/valid/valid/21334.txt
# /kaggle/input/valid/valid/21874.txt
# /kaggle/input/valid/valid/20976.txt
# /kaggle/input/valid/valid/4998.txt
# /kaggle/input/valid/valid/5755.txt
# /kaggle/input/valid/valid/18975.txt
# /kaggle/input/valid/valid/15930.txt
# /kaggle/input/valid/valid/21212.txt
# /kaggle/input/valid/valid/9459.txt
# /kaggle/input/valid/valid/18476.txt
# /kaggle/input/valid/valid/18144.txt
# /kaggle/input/valid/valid/7931.txt
# /kaggle/input/valid/valid/3437.txt
# /kaggle/input/valid/valid/16099.txt
# /kaggle/input/valid/valid/17977.txt
# /kaggle/input/valid/valid/17363.txt
# /kaggle/input/valid/valid/8560.txt
# /kaggle/input/valid/valid/11809.txt
# /kaggle/input/valid/valid/17798.txt
# /kaggle/input/valid/valid/1172.txt
# /kaggle/input/valid/valid/19558.txt
# /kaggle/input/valid/valid/21603.txt
# /kaggle/input/valid/valid/17686.txt
# /kaggle/input/valid/valid/3192.txt
# /kaggle/input/valid/valid/2009.txt
# /kaggle/input/valid/valid/3082.txt
# /kaggle/input/valid/valid/16807.txt
# /kaggle/input/valid/valid/19416.txt
# /kaggle/input/valid/valid/3179.txt
# /kaggle/input/valid/valid/15137.txt
# /kaggle/input/valid/valid/1989.txt
# /kaggle/input/valid/valid/16742.txt
# /kaggle/input/valid/valid/10644.txt
# /kaggle/input/valid/valid/2007.txt
# /kaggle/input/valid/valid/2855.txt
# /kaggle/input/valid/valid/14462.txt
# /kaggle/input/valid/valid/13223.txt
# /kaggle/input/valid/valid/1444.txt
# /kaggle/input/valid/valid/7484.txt
# /kaggle/input/valid/valid/21588.txt
# /kaggle/input/valid/valid/14372.txt
# /kaggle/input/valid/valid/20254.txt
# /kaggle/input/valid/valid/9316.txt
# /kaggle/input/valid/valid/12130.txt
# /kaggle/input/valid/valid/12489.txt
# /kaggle/input/valid/valid/1885.txt
# /kaggle/input/valid/valid/19750.txt
# /kaggle/input/valid/valid/20176.txt
# ...
# /kaggle/input/train/train/8221.txt
# /kaggle/input/train/train/17718.txt
# /kaggle/input/train/train/16487.txt
# /kaggle/input/train/train/16346.txt
# /kaggle/input/train/train/600.txt
# /kaggle/input/train/train/11859.txt
# /kaggle/input/train/train/18914.txt
# /kaggle/input/train/train/1619.txt
# /kaggle/input/train/train/3684.txt
# /kaggle/input/train/train/17355.txt
# /kaggle/input/train/train/18227.txt
# /kaggle/input/train/train/20452.txt
# /kaggle/input/train/train/7480.txt
# /kaggle/input/train/train/1703.txt
# /kaggle/input/train/train/18693.txt
# /kaggle/input/train/train/5895.txt
# /kaggle/input/train/train/8612.txt
# /kaggle/input/train/train/8360.txt
# /kaggle/input/train/train/6276.txt
# /kaggle/input/train/train/4276.txt
# /kaggle/input/train/train/20655.txt
# /kaggle/input/train/train/15882.txt
# /kaggle/input/train/train/5138.txt
# /kaggle/input/train/train/15668.txt
# /kaggle/input/train/train/2048.txt
# /kaggle/input/train/train/365.txt
# /kaggle/input/train/train/10821.txt
# /kaggle/input/train/train/15948.txt
# /kaggle/input/train/train/21100.txt
# /kaggle/input/train/train/18965.txt
# /kaggle/input/train/train/20820.txt
# /kaggle/input/train/train/2451.txt
# /kaggle/input/train/train/11389.txt
# /kaggle/input/train/train/21531.txt
# /kaggle/input/train/train/9461.txt
# /kaggle/input/train/train/1906.txt
# /kaggle/input/train/train/4137.txt
# /kaggle/input/train/train/20369.txt
# /kaggle/input/train/train/20032.txt
# /kaggle/input/train/train/8218.txt
# /kaggle/input/train/train/13958.txt
# /kaggle/input/train/train/927.txt
# /kaggle/input/train/train/15047.txt
# /kaggle/input/train/train/18769.txt
# /kaggle/input/train/train/20504.txt
# /kaggle/input/train/train/18718.txt
# /kaggle/input/train/train/17401.txt
# /kaggle/input/train/train/17275.txt
# /kaggle/input/train/train/17069.txt
# /kaggle/input/train/train/10769.txt
# /kaggle/input/train/train/1422.txt
# /kaggle/input/train/train/8374.txt
# /kaggle/input/train/train/19914.txt
# /kaggle/input/train/train/16622.txt
# /kaggle/input/train/train/9989.txt
# /kaggle/input/train/train/14147.txt
# /kaggle/input/train/train/4717.txt
# /kaggle/input/train/train/4694.txt
# /kaggle/input/train/train/20201.txt
# /kaggle/input/train/train/3227.txt
# /kaggle/input/train/train/11969.txt
# /kaggle/input/train/train/12219.txt
# /kaggle/input/train/train/9655.txt
# /kaggle/input/train/train/6446.txt
# /kaggle/input/train/train/11745.txt
# /kaggle/input/train/train/17812.txt
# /kaggle/input/train/train/849.txt
# /kaggle/input/train/train/21698.txt
# /kaggle/input/train/train/11841.txt
# /kaggle/input/train/train/7003.txt
# /kaggle/input/train/train/6578.txt
# /kaggle/input/train/train/7756.txt
# /kaggle/input/train/train/22229.txt
# /kaggle/input/train/train/387.txt
# /kaggle/input/train/train/10088.txt
# /kaggle/input/train/train/15631.txt
# /kaggle/input/train/train/19779.txt
# /kaggle/input/train/train/17847.txt
# /kaggle/input/train/train/10458.txt
# /kaggle/input/train/train/11064.txt
# /kaggle/input/train/train/3084.txt
# /kaggle/input/train/train/5193.txt
# /kaggle/input/train/train/5769.txt
# /kaggle/input/train/train/18807.txt
# /kaggle/input/train/train/20934.txt
# /kaggle/input/train/train/604.txt
# /kaggle/input/train/train/3640.txt
# /kaggle/input/train/train/17057.txt
# /kaggle/input/train/train/14815.txt
# /kaggle/input/train/train/13997.txt
# /kaggle/input/train/train/2162.txt
# /kaggle/input/train/train/19481.txt
# /kaggle/input/train/train/17725.txt
# /kaggle/input/train/train/21026.txt
# /kaggle/input/train/train/8494.txt
# /kaggle/input/train/train/12707.txt
# /kaggle/input/train/train/4015.txt
# /kaggle/input/train/train/12395.txt
# /kaggle/input/train/train/15069.txt
# /kaggle/input/train/train/13122.txt
# /kaggle/input/train/train/17964.txt
# /kaggle/input/train/train/9460.txt
# /kaggle/input/train/train/7152.txt
# /kaggle/input/train/train/9532.txt
# /kaggle/input/train/train/21097.txt
# /kaggle/input/train/train/2357.txt
# /kaggle/input/train/train/15159.txt
# /kaggle/input/train/train/6786.txt
# /kaggle/input/train/train/10835.txt
# /kaggle/input/train/train/22005.txt
# /kaggle/input/train/train/18713.txt
# /kaggle/input/train/train/4275.txt
# /kaggle/input/train/train/3010.txt
# /kaggle/input/train/train/10247.txt
# /kaggle/input/train/train/2049.txt
# /kaggle/input/train/train/21415.txt
# /kaggle/input/train/train/15909.txt
# /kaggle/input/train/train/14965.txt
# /kaggle/input/train/train/19296.txt
# /kaggle/input/train/train/11243.txt
# /kaggle/input/train/train/5068.txt
# /kaggle/input/train/train/847.txt
# /kaggle/input/train/train/10255.txt
# /kaggle/input/train/train/16680.txt
# /kaggle/input/train/train/12849.txt
# /kaggle/input/train/train/21491.txt
# /kaggle/input/train/train/12617.txt
# /kaggle/input/train/train/20953.txt
# /kaggle/input/train/train/11784.txt
# /kaggle/input/train/train/14058.txt
# /kaggle/input/train/train/20602.txt
# /kaggle/input/train/train/3576.txt
# /kaggle/input/train/train/10235.txt
# /kaggle/input/train/train/4789.txt
# /kaggle/input/train/train/4711.txt
# /kaggle/input/train/train/14922.txt
# /kaggle/input/train/train/5149.txt
# /kaggle/input/train/train/7501.txt
# /kaggle/input/train/train/10683.txt
# /kaggle/input/train/train/15034.txt
# /kaggle/input/train/train/4194.txt
# /kaggle/input/train/train/15674.txt
# /kaggle/input/train/train/14491.txt
# /kaggle/input/train/train/5773.txt
# /kaggle/input/train/train/10831.txt
# /kaggle/input/train/train/9836.txt
# /kaggle/input/train/train/4384.txt
# /kaggle/input/train/train/22187.txt
# /kaggle/input/train/train/20917.txt
# /kaggle/input/train/train/12141.txt
# /kaggle/input/train/train/11967.txt
# /kaggle/input/train/train/22153.txt
# /kaggle/input/train/train/12085.txt
# /kaggle/input/train/train/765.txt
# /kaggle/input/train/train/10090.txt
# /kaggle/input/train/train/17416.txt
# /kaggle/input/train/train/3665.txt
# /kaggle/input/train/train/21930.txt
# /kaggle/input/train/train/6984.txt
# /kaggle/input/train/train/19742.txt
# /kaggle/input/train/train/1532.txt
# /kaggle/input/train/train/12551.txt
# /kaggle/input/train/train/12654.txt
# /kaggle/input/train/train/1044.txt
# /kaggle/input/train/train/18944.txt
# /kaggle/input/train/train/848.txt
# /kaggle/input/train/train/21062.txt
# /kaggle/input/train/train/1218.txt
# /kaggle/input/train/train/13173.txt
# /kaggle/input/train/train/21894.txt
# /kaggle/input/train/train/2719.txt
# /kaggle/input/train/train/2188.txt
# /kaggle/input/train/train/19255.txt
# /kaggle/input/train/train/8519.txt
# /kaggle/input/train/train/6437.txt
# /kaggle/input/train/train/18577.txt
# /kaggle/input/train/train/8485.txt
# /kaggle/input/train/train/5168.txt
# /kaggle/input/train/train/6229.txt
# /kaggle/input/train/train/19058.txt
# /kaggle/input/train/train/6042.txt
# /kaggle/input/train/train/15188.txt
# /kaggle/input/train/train/4985.txt
# /kaggle/input/train/train/7716.txt
# /kaggle/input/train/train/13644.txt
# /kaggle/input/train/train/17501.txt
# /kaggle/input/train/train/4373.txt
# /kaggle/input/train/train/15088.txt
# /kaggle/input/train/train/7885.txt
# /kaggle/input/train/train/11472.txt
# /kaggle/input/train/train/16893.txt
# /kaggle/input/train/train/21286.txt
# /kaggle/input/train/train/11342.txt
# /kaggle/input/train/train/18653.txt
# /kaggle/input/train/train/6304.txt
# /kaggle/input/train/train/14515.txt
# /kaggle/input/train/train/16902.txt
# /kaggle/input/train/train/14525.txt
# /kaggle/input/train/train/5061.txt
# /kaggle/input/train/train/11333.txt
# /kaggle/input/train/train/9615.txt
# /kaggle/input/train/train/5548.txt
# /kaggle/input/train/train/6174.txt
# /kaggle/input/train/train/19251.txt
# /kaggle/input/train/train/10932.txt
# /kaggle/input/train/train/145.txt
# /kaggle/input/train/train/18523.txt
# /kaggle/input/train/train/10063.txt
# /kaggle/input/train/train/4780.txt
# /kaggle/input/train/train/20212.txt
# /kaggle/input/train/train/11769.txt
# /kaggle/input/train/train/2941.txt
# /kaggle/input/train/train/21736.txt
# /kaggle/input/train/train/3675.txt
# /kaggle/input/train/train/12488.txt
# /kaggle/input/train/train/15685.txt
# /kaggle/input/train/train/15449.txt
# /kaggle/input/train/train/16840.txt
# /kaggle/input/train/train/8297.txt
# /kaggle/input/train/train/5294.txt
# /kaggle/input/train/train/14788.txt
# /kaggle/input/train/train/12600.txt
# /kaggle/input/train/train/4002.txt
# /kaggle/input/train/train/18727.txt
# /kaggle/input/train/train/10429.txt
# /kaggle/input/train/train/18070.txt
# /kaggle/input/train/train/20961.txt
# /kaggle/input/train/train/1977.txt
# /kaggle/input/train/train/8868.txt
# /kaggle/input/train/train/4106.txt
# /kaggle/input/train/train/5744.txt
# /kaggle/input/train/train/11051.txt
# /kaggle/input/train/train/314.txt
# /kaggle/input/train/train/1528.txt
# /kaggle/input/train/train/5625.txt
# /kaggle/input/train/train/15514.txt
# /kaggle/input/train/train/17887.txt
# /kaggle/input/train/train/21085.txt
# /kaggle/input/train/train/9480.txt
# /kaggle/input/train/train/5544.txt
# /kaggle/input/train/train/22262.txt
# /kaggle/input/train/train/20817.txt
# /kaggle/input/train/train/11768.txt
# /kaggle/input/train/train/7580.txt
# /kaggle/input/train/train/2950.txt
# /kaggle/input/train/train/18454.txt
# /kaggle/input/train/train/20262.txt
# /kaggle/input/train/train/10565.txt
# /kaggle/input/train/train/20693.txt
# /kaggle/input/train/train/8377.txt
# /kaggle/input/train/train/1570.txt
# /kaggle/input/train/train/15713.txt
# /kaggle/input/train/train/7023.txt
# /kaggle/input/train/train/1728.txt
# /kaggle/input/train/train/4992.txt
# /kaggle/input/train/train/8525.txt
# /kaggle/input/train/train/20094.txt
# /kaggle/input/train/train/788.txt
# /kaggle/input/train/train/6701.txt
# /kaggle/input/train/train/13361.txt
# /kaggle/input/train/train/9382.txt
# /kaggle/input/train/train/18738.txt
# /kaggle/input/train/train/12685.txt
# /kaggle/input/train/train/18723.txt
# /kaggle/input/train/train/4264.txt
# /kaggle/input/train/train/19380.txt
# /kaggle/input/train/train/4633.txt
# /kaggle/input/train/train/13558.txt
# /kaggle/input/train/train/16545.txt
# /kaggle/input/train/train/18183.txt
# /kaggle/input/train/train/17548.txt
# /kaggle/input/train/train/8402.txt
# /kaggle/input/train/train/18366.txt
# /kaggle/input/train/train/12371.txt
# /kaggle/input/train/train/6369.txt
# /kaggle/input/train/train/19621.txt
# /kaggle/input/train/train/2019.txt
# /kaggle/input/train/train/13014.txt
# /kaggle/input/train/train/5494.txt
# /kaggle/input/train/train/9780.txt
# /kaggle/input/train/train/405.txt
# /kaggle/input/train/train/8275.txt
# /kaggle/input/train/train/21602.txt
# /kaggle/input/train/train/19415.txt
# /kaggle/input/train/train/12375.txt
# /kaggle/input/train/train/7659.txt
# /kaggle/input/train/train/12285.txt
# /kaggle/input/train/train/13156.txt
# /kaggle/input/train/train/13843.txt
# /kaggle/input/train/train/7668.txt
# /kaggle/input/train/train/17395.txt
# /kaggle/input/train/train/8605.txt
# /kaggle/input/train/train/21392.txt
# /kaggle/input/train/train/16731.txt
# /kaggle/input/train/train/16050.txt
# /kaggle/input/train/train/19253.txt
# /kaggle/input/train/train/14873.txt
# /kaggle/input/train/train/4405.txt
# /kaggle/input/train/train/8274.txt
# /kaggle/input/train/train/4131.txt
# /kaggle/input/train/train/18106.txt
# /kaggle/input/train/train/10310.txt
# /kaggle/input/train/train/13702.txt
# /kaggle/input/train/train/13137.txt
# /kaggle/input/train/train/3190.txt
# /kaggle/input/train/train/623.txt
# /kaggle/input/train/train/2052.txt
# /kaggle/input/train/train/22100.txt
# /kaggle/input/train/train/7202.txt
# /kaggle/input/train/train/9536.txt
# /kaggle/input/train/train/8240.txt
# /kaggle/input/train/train/12226.txt
# /kaggle/input/train/train/10630.txt
# /kaggle/input/train/train/8367.txt
# /kaggle/input/train/train/1087.txt
# /kaggle/input/train/train/18732.txt
# /kaggle/input/train/train/6465.txt
# /kaggle/input/train/train/2525.txt
# /kaggle/input/train/train/11461.txt
# /kaggle/input/train/train/12394.txt
# /kaggle/input/train/train/21866.txt
# /kaggle/input/train/train/2722.txt
# /kaggle/input/train/train/839.txt
# /kaggle/input/train/train/5179.txt
# /kaggle/input/train/train/2132.txt
# /kaggle/input/train/train/13948.txt
# /kaggle/input/train/train/11543.txt
# /kaggle/input/train/train/11070.txt
# /kaggle/input/train/train/100.txt
# /kaggle/input/train/train/19845.txt
# /kaggle/input/train/train/9969.txt
# /kaggle/input/train/train/19266.txt
# /kaggle/input/train/train/11394.txt
# /kaggle/input/train/train/16727.txt
# /kaggle/input/train/train/4772.txt
# /kaggle/input/train/train/12477.txt
# /kaggle/input/train/train/14653.txt
# /kaggle/input/train/train/21427.txt
# /kaggle/input/train/train/8390.txt
# /kaggle/input/train/train/16578.txt
# /kaggle/input/train/train/9083.txt
# /kaggle/input/train/train/13305.txt
# /kaggle/input/train/train/11893.txt
# /kaggle/input/train/train/10475.txt
# /kaggle/input/train/train/947.txt
# /kaggle/input/train/train/12195.txt
# /kaggle/input/train/train/13964.txt
# /kaggle/input/train/train/3399.txt
# /kaggle/input/train/train/5734.txt
# /kaggle/input/train/train/18748.txt
# /kaggle/input/train/train/10875.txt
# /kaggle/input/train/train/16170.txt
# /kaggle/input/train/train/16098.txt
# /kaggle/input/train/train/12261.txt
# /kaggle/input/train/train/13009.txt
# /kaggle/input/train/train/9871.txt
# /kaggle/input/train/train/3401.txt
# /kaggle/input/train/train/15673.txt
# /kaggle/input/train/train/8897.txt
# /kaggle/input/train/train/12978.txt
# /kaggle/input/train/train/6116.txt
# /kaggle/input/train/train/2483.txt
# /kaggle/input/train/train/22190.txt
# /kaggle/input/train/train/7828.txt
# /kaggle/input/train/train/9174.txt
# /kaggle/input/train/train/16148.txt
# /kaggle/input/train/train/9183.txt
# /kaggle/input/train/train/10730.txt
# /kaggle/input/train/train/14150.txt
# /kaggle/input/train/train/4528.txt
# /kaggle/input/train/train/17833.txt
# /kaggle/input/train/train/20880.txt
# /kaggle/input/train/train/19023.txt
# /kaggle/input/train/train/15551.txt
# /kaggle/input/train/train/11283.txt
# /kaggle/input/train/train/7275.txt
# /kaggle/input/train/train/19728.txt
# /kaggle/input/train/train/13666.txt
# /kaggle/input/train/train/18301.txt
# /kaggle/input/train/train/2732.txt
# /kaggle/input/train/train/10030.txt
# /kaggle/input/train/train/9160.txt
# /kaggle/input/train/train/14816.txt
# /kaggle/input/train/train/8202.txt
# /kaggle/input/train/train/2519.txt
# /kaggle/input/train/train/4083.txt
# /kaggle/input/train/train/11181.txt
# /kaggle/input/train/train/18586.txt
# /kaggle/input/train/train/13033.txt
# /kaggle/input/train/train/15955.txt
# /kaggle/input/train/train/14808.txt
# /kaggle/input/train/train/21242.txt
# /kaggle/input/train/train/2621.txt
# /kaggle/input/train/train/19308.txt
# /kaggle/input/train/train/11560.txt
# /kaggle/input/train/train/13876.txt
# /kaggle/input/train/train/8280.txt
# /kaggle/input/train/train/5723.txt
# /kaggle/input/train/train/11311.txt
# /kaggle/input/train/train/7400.txt
# /kaggle/input/train/train/883.txt
# /kaggle/input/train/train/14358.txt
# /kaggle/input/train/train/6962.txt
# /kaggle/input/train/train/14159.txt
# /kaggle/input/train/train/20507.txt
# /kaggle/input/train/train/3881.txt
# /kaggle/input/train/train/14366.txt
# /kaggle/input/train/train/7671.txt
# /kaggle/input/train/train/7583.txt
# /kaggle/input/train/train/6277.txt
# /kaggle/input/train/train/13926.txt
# /kaggle/input/train/train/15203.txt
# /kaggle/input/train/train/13987.txt
# /kaggle/input/train/train/16721.txt
# /kaggle/input/train/train/17527.txt
# /kaggle/input/train/train/1406.txt
# /kaggle/input/train/train/15796.txt
# /kaggle/input/train/train/12752.txt
# /kaggle/input/train/train/22144.txt
# /kaggle/input/train/train/1809.txt
# /kaggle/input/train/train/16658.txt
# /kaggle/input/train/train/3834.txt
# /kaggle/input/train/train/1508.txt
# /kaggle/input/train/train/7451.txt
# /kaggle/input/train/train/17495.txt
# /kaggle/input/train/train/10530.txt
# /kaggle/input/train/train/21670.txt
# /kaggle/input/train/train/15861.txt
# /kaggle/input/train/train/12545.txt
# /kaggle/input/train/train/9719.txt
# /kaggle/input/train/train/13294.txt
# /kaggle/input/train/train/1025.txt
# /kaggle/input/train/train/17182.txt
# /kaggle/input/train/train/8307.txt
# /kaggle/input/train/train/16229.txt
# /kaggle/input/train/train/11614.txt
# /kaggle/input/train/train/3929.txt
# /kaggle/input/train/train/4470.txt
# /kaggle/input/train/train/17782.txt
# /kaggle/input/train/train/2129.txt
# /kaggle/input/train/train/15563.txt
# /kaggle/input/train/train/10313.txt
# /kaggle/input/train/train/22033.txt
# /kaggle/input/train/train/15281.txt
# /kaggle/input/train/train/13713.txt
# /kaggle/input/train/train/5118.txt
# /kaggle/input/train/train/3769.txt
# /kaggle/input/train/train/597.txt
# /kaggle/input/train/train/11681.txt
# /kaggle/input/train/train/2886.txt

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Oh, no! There are no automatic insights available for the file types used in this dataset. As your Kaggle kerneler bot, I'll keep working to fine-tune my hyper-parameters. In the meantime, please feel free to try a different dataset.

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Fork Notebook" button at the top of this kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
